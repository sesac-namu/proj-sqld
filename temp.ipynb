# %%
import pandas as pd

# %%
df = pd.read_csv('data/E_miracle_data.csv', encoding='utf-8')
df.shape
# Out:
# (2500, 8)

# %%
df.drop_duplicates().reset_index().drop(['index'], axis=1)
# Out:
#                                                  title  \
# 0                                 다음의 예에서 결괏값이 다른 하나는?
# 1    학생(STUDENT) 테이블에 영문학과 학생 50명, 법학과 학생 100명, 수학과...
# 2    {학번, 과목번호}는 결정자이면서 기본키이고 {성적, 지도교수명, 학과명}은 종속자...
# 3                  발생 시점에 따른 엔터티 분류에 의한 중심 엔터티가 아닌 것은?
# 4    다음 주어진 테이블에 대해서 아래와 같은 결과값이 반환되도록 아래 SQL문의 빈칸에...
# ..                                                 ...
# 324                           데이터 모델링에 대한 설명 중 알맞은 것은?
# 325                      다음의 SQL문에 대한 설명으로 올바르지 않은 것은?
# 326  아래와 같은 테이블 TAB1, TAB2가 있을 때 아래 SQL의 결과 건수를 알맞게...
# 327                       다음 서브쿼리에 대한 설명 중 틀린 것을 고르시오.
# 328       데이터 모델링에 대한 단계 중 아래에서 설명하는 단계는 어떤 단계의 모델링인가?
#
#                                       content_img  content_text  \
# 0    https://cbt.youngjin.com/upload/sqld/133.png           NaN
# 1                                             NaN           NaN
# 2     https://cbt.youngjin.com/upload/sqld/19.png           NaN
# ...

# %%
df.head()
# Out:
#                                                title  \
# 0                               다음의 예에서 결괏값이 다른 하나는?
# 1  학생(STUDENT) 테이블에 영문학과 학생 50명, 법학과 학생 100명, 수학과...
# 2  {학번, 과목번호}는 결정자이면서 기본키이고 {성적, 지도교수명, 학과명}은 종속자...
# 3                발생 시점에 따른 엔터티 분류에 의한 중심 엔터티가 아닌 것은?
# 4  다음 주어진 테이블에 대해서 아래와 같은 결과값이 반환되도록 아래 SQL문의 빈칸에...
#
#                                     content_img  content_text  \
# 0  https://cbt.youngjin.com/upload/sqld/133.png           NaN
# 1                                           NaN           NaN
# 2   https://cbt.youngjin.com/upload/sqld/19.png           NaN
# 3                                           NaN           NaN
# 4   https://cbt.youngjin.com/upload/sqld/72.png           NaN
#
#                           choices_1                         choices_2  \
# 0       SELECT NULL*2 FROM SQLD_13;       SELECT NULL*3 FROM SQLD_13;
# 1               ㄱ : 3, ㄴ : 3, ㄷ : 1             ㄱ : 200, ㄴ : 3, ㄷ : 1
# ...

# %%
from glob import glob

files = glob('data/sqld_kr_data_*.csv')
files
dfs = []
for file in files:
    df = pd.read_csv(file, encoding='utf-8')
    dfs.append(df)

df = pd.concat(dfs)
df.shape
# df.to_csv('./data/sqld_kr_data.csv', encoding='utf-8', index=0)
# Out:
# (28304, 10)

# %%
df = pd.read_csv('./data/sqld_kr_data.csv', encoding='utf-8')
df.shape
# Out:
# (28304, 10)

# %%
df.drop([ 'id', 'page_id'], axis=1).drop_duplicates().reset_index()
# Out:
#      index                                              title  \
# 0        0  다음 중 SELECT COL1 + COL3 FROM TAB_A； 의 결과로 가장 적...
# 1        1                 다음 주어진 ERD 관계에 대한 설명으로 옳은 것을 고르시오.
# 2        2  두 개 릴레이션 Student와 Department가 있을 때, 질의문 "SELEC...
# 3        3                    다음 중 속성에 대한 설명 중 가장 적절하지 않은 것은?
# 4        4  다음은 데이터베이스 모델링 시에 성능을 고려한 모델링 활동이다. 성능을 고려한 데이...
# ..     ...                                                ...
# 795   4644             다음 중 데이터베이스 논리 모델에 대한 설명으로 올바르지 않은 것은?
# 796   4645                          다음 설명에 해당하는 모델링 관점은 무엇인가?
# 797   5083                  다음 중 주어진 테이블을 수행하였을 때 결괏값이 다른 것은?
# 798   5495                    다음 중 분산 데이터베이스의 투명성에 속하지 않는 것은?
# 799   7021                       ORDER BY에 대한 설명으로 가장 적절한 것은?
#
#                                            content_img  \
# 0    https://sqld-bk.s3.ap-southeast-2.amazonaws.co...
# 1    https://sqld-bk.s3.ap-southeast-2.amazonaws.co...
# ...

# %%
import pandas as pd

df = pd.read_csv('data/first_df.csv', encoding='utf-8', index_col=0)
df.shape
# Out:
# (1215, 8)

# %%
df = pd.read_csv('data/data_1.csv', encoding='utf-8', index_col=False)
df.shape
# Out:
# (500, 8)

# %%
# 판다스 데이터프레임에 바로 사용할 수 있는 배열들

categories = ["2과목", "1과목", "2과목", "2과목", "2과목", "2과목", "2과목", "2과목", "2과목", "2과목", "2과목", "2과목", "2과목", "2과목", "2과목", "2과목", "2과목", "2과목", "2과목", "2과목", "1과목", "2과목", "1과목", "2과목", "2과목", "2과목", "2과목", "2과목", "2과목", "2과목", "2과목", "2과목", "2과목", "1과목", "2과목", "2과목", "2과목", "2과목", "2과목", "1과목", "2과목", "2과목", "2과목", "2과목", "2과목", "2과목", "2과목", "2과목", "2과목", "2과목", "2과목", "2과목", "2과목", "2과목", "2과목", "2과목", "2과목", "1과목", "2과목", "1과목", "1과목", "1과목", "2과목", "2과목", "2과목", "2과목", "1과목", "2과목", "2과목", "2과목", "2과목", "2과목", "2과목", "2과목", "1과목", "1과목", "2과목", "2과목", "2과목", "2과목", "2과목", "2과목", "1과목", "2과목", "2과목", "2과목", "2과목", "2과목", "1과목", "2과목", "2과목", "2과목", "2과목", "2과목", "2과목", "2과목", "2과목", "2과목", "1과목", "2과목", "2과목", "2과목", "2과목", "1과목", "2과목", "1과목", "1과목", "2과목", "2과목", "2과목", "2과목", "2과목", "2과목", "2과목", "2과목", "2과목", "2과목", "1과목", "1과목", "1과목", "2과목", "2과목", "2과목", "2과목", "2과목", "2과목", "2과목", "2과목", "2과목", "2과목", "2과목", "2과목", "2과목", "1과목", "1과목", "1과목", "1과목", "1과목", "2과목", "2과목", "2과목", "2과목", "2과목", "2과목", "2과목", "2과목", "2과목", "2과목", "2과목", "2과목", "2과목", "2과목", "2과목", "2과목", "2과목", "2과목", "2과목", "2과목", "2과목", "2과목", "2과목", "2과목", "2과목", "2과목", "2과목", "2과목", "2과목", "2과목", "1과목", "2과목", "2과목", "2과목", "2과목", "2과목", "2과목", "2과목", "2과목", "2과목", "2과목", "2과목", "2과목", "2과목", "2과목", "1과목", "1과목", "2과목", "2과목", "2과목", "1과목", "1과목", "2과목", "2과목", "2과목", "2과목", "2과목", "2과목", "2과목", "2과목", "2과목", "2과목", "2과목", "2과목", "2과목", "2과목", "2과목", "2과목", "1과목", "2과목", "2과목", "2과목", "2과목", "2과목", "2과목", "2과목", "2과목", "2과목", "1과목", "1과목", "2과목", "2과목", "2과목", "1과목", "2과목", "1과목", "2과목", "2과목", "2과목", "2과목", "2과목", "2과목", "2과목", "2과목", "2과목", "2과목", "2과목", "2과목", "2과목", "2과목", "2과목", "2과목", "2과목", "2과목", "2과목", "2과목", "2과목", "2과목", "2과목", "1과목", "2과목", "2과목", "2과목", "1과목", "2과목", "2과목", "2과목", "2과목", "1과목", "2과목", "2과목", "2과목", "2과목", "2과목", "2과목", "2과목", "2과목", "2과목", "2과목", "2과목", "1과목", "2과목", "2과목", "2과목", "2과목", "2과목", "2과목", "2과목", "2과목", "2과목", "1과목", "2과목", "2과목", "1과목", "2과목", "2과목", "2과목", "2과목", "2과목", "2과목", "2과목", "1과목", "2과목", "2과목", "2과목", "2과목", "2과목", "2과목", "1과목", "1과목", "1과목", "1과목", "2과목", "1과목", "1과목", "2과목", "2과목", "1과목", "1과목", "1과목", "1과목", "1과목", "2과목", "2과목", "1과목", "1과목", "2과목", "2과목", "1과목", "1과목", "2과목", "2과목", "2과목", "1과목", "1과목", "2과목", "2과목", "2과목", "1과목", "1과목", "1과목", "1과목", "1과목", "1과목", "2과목", "2과목", "2과목", "2과목", "2과목", "2과목", "2과목", "2과목", "2과목", "2과목", "2과목", "1과목", "2과목", "2과목", "2과목", "2과목", "2과목", "2과목", "2과목", "2과목", "2과목", "2과목", "2과목", "2과목", "2과목", "1과목", "1과목", "1과목", "2과목", "2과목", "2과목", "1과목", "2과목", "2과목", "2과목", "2과목", "2과목", "1과목", "1과목", "1과목", "2과목", "2과목", "1과목", "2과목", "2과목", "2과목", "2과목", "2과목", "2과목", "2과목", "1과목", "2과목", "2과목", "2과목", "2과목", "1과목", "1과목", "2과목", "2과목", "1과목", "2과목", "2과목", "1과목", "2과목", "2과목", "2과목", "2과목", "2과목", "1과목", "2과목", "2과목", "2과목", "2과목", "2과목", "2과목", "2과목", "2과목", "2과목", "1과목", "2과목", "2과목", "1과목", "2과목", "1과목", "1과목", "1과목", "2과목", "1과목", "1과목", "1과목", "2과목", "2과목", "2과목", "2과목", "2과목", "2과목", "2과목", "2과목", "2과목", "2과목", "2과목", "1과목", "2과목", "2과목", "2과목", "2과목", "1과목", "2과목", "2과목", "1과목", "2과목", "2과목", "2과목", "1과목", "2과목", "2과목", "2과목", "2과목", "2과목", "2과목", "2과목", "1과목", "2과목", "1과목", "1과목", "2과목", "2과목", "1과목", "1과목", "1과목", "1과목", "1과목", "2과목", "2과목", "2과목", "2과목", "1과목", "2과목", "2과목", "2과목", "1과목", "1과목", "1과목", "1과목", "2과목", "1과목", "1과목", "2과목", "2과목", "2과목", "1과목", "1과목", "1과목", "1과목", "1과목", "2과목", "1과목", "1과목", "1과목", "2과목", "2과목", "2과목", "2과목", "2과목", "2과목", "2과목", "2과목", "2과목"]

tags = ["기본 조회", "ER 모델링", "조인", "집계 함수", "조건문/변환함수", "조건문/변환함수", "조인", "기타", "서브쿼리", "조인", "기타", "기타", "서브쿼리", "그룹 함수", "키 관리", "집합 연산자", "윈도우 함수", "조인", "DML", "DML", "ER 모델링", "기타", "ER 모델링", "그룹 함수", "서브쿼리", "그룹 함수", "기본 조회", "그룹 함수", "기본 조회", "집계 함수", "그룹 함수", "집계 함수", "기타", "ER 모델링", "기타", "기본 조회", "집계 함수", "집합 연산자", "집계 함수", "기타", "기타", "조인", "집계 함수", "집계 함수", "ER 모델링", "그룹 함수", "집계 함수", "그룹 함수", "집계 함수", "윈도우 함수", "그룹 함수", "기타", "조건문/변환함수", "그룹 함수", "기본 조회", "조건문/변환함수", "조건문/변환함수", "데이터 무결성", "기타", "ER 모델링", "정규화", "키 관리", "기타", "그룹 함수", "기타", "집계 함수", "ER 모델링", "기타", "기타", "키 관리", "윈도우 함수", "기본 조회", "DML", "그룹 함수", "기타", "조인", "그룹 함수", "집계 함수", "조인", "기타", "기본 조회", "기본 조회", "기타", "서브쿼리", "서브쿼리", "기본 조회", "기타", "기타", "ER 모델링", "기본 조회", "집계 함수", "그룹 함수", "집계 함수", "조인", "조건문/변환함수", "조인", "서브쿼리", "기본 조회", "ER 모델링", "집합 연산자", "기타", "집계 함수", "조인", "기타", "그룹 함수", "ER 모델링", "키 관리", "그룹 함수", "윈도우 함수", "윈도우 함수", "조인", "기타", "조건문/변환함수", "집계 함수", "집계 함수", "기본 조회", "그룹 함수", "ER 모델링", "ER 모델링", "ER 모델링", "조인", "기타", "집계 함수", "기타", "ER 모델링", "조인", "윈도우 함수", "윈도우 함수", "기타", "조인", "기본 조회", "윈도우 함수", "집계 함수", "ER 모델링", "ER 모델링", "ER 모델링", "ER 모델링", "ER 모델링", "그룹 함수", "기타", "서브쿼리", "윈도우 함수", "ER 모델링", "조인", "기타", "조인", "서브쿼리", "기본 조회", "집합 연산자", "집계 함수", "집계 함수", "집계 함수", "그룹 함수", "집계 함수", "기본 조회", "집합 연산자", "집계 함수", "조인", "집합 연산자", "기타", "집계 함수", "조건문/변환함수", "집계 함수", "기본 조회", "그룹 함수", "기타", "기본 조회", "기타", "ER 모델링", "조인", "기타", "기타", "윈도우 함수", "집합 연산자", "그룹 함수", "DML", "조인", "윈도우 함수", "조인", "기타", "조건문/변환함수", "기본 조회", "기본 조회", "기타", "기타", "조인", "ER 모델링", "윈도우 함수", "ER 모델링", "ER 모델링", "조건문/변환함수", "윈도우 함수", "기타", "윈도우 함수", "조건문/변환함수", "조인", "윈도우 함수", "기타", "기타", "DML", "조건문/변환함수", "그룹 함수", "집합 연산자", "윈도우 함수", "조인", "그룹 함수", "기타", "기타", "집계 함수", "조인", "기본 조회", "조건문/변환함수", "집합 연산자", "조인", "기타", "윈도우 함수", "ER 모델링", "기타", "윈도우 함수", "기타", "DML", "ER 모델링", "기타", "ER 모델링", "집계 함수", "조인", "서브쿼리", "그룹 함수", "기본 조회", "기본 조회", "집계 함수", "기타", "집계 함수", "집계 함수", "트랜잭션", "조인", "기타", "집합 연산자", "조인", "그룹 함수", "조건문/변환함수", "기타", "기타", "서브쿼리", "그룹 함수", "ER 모델링", "조인", "ER 모델링", "집계 함수", "서브쿼리", "조건문/변환함수", "기타", "기타", "DML", "조건문/변환함수", "조인", "ER 모델링", "기본 조회", "집계 함수", "기타", "조인", "서브쿼리", "기타", "조건문/변환함수", "조인", "기타", "그룹 함수", "조건문/변환함수", "기타", "조인", "기타", "기본 조회", "기본 조회", "집계 함수", "기본 조회", "기본 조회", "기타", "기본 조회", "ER 모델링", "집계 함수", "윈도우 함수", "ER 모델링", "기타", "기타", "윈도우 함수", "키 관리", "그룹 함수", "그룹 함수", "그룹 함수", "ER 모델링", "기본 조회", "기본 조회", "조인", "기타", "기타", "서브쿼리", "ER 모델링", "ER 모델링", "조건문/변환함수", "기타", "윈도우 함수", "키 관리", "ER 모델링", "기타", "집계 함수", "기타", "기타", "정규화", "기타", "데이터 무결성", "DML", "조인", "서브쿼리", "조인", "조인", "기타", "기타", "기타", "집합 연산자", "윈도우 함수", "조인", "기타", "기타", "기타", "조인", "그룹 함수", "기타", "ER 모델링", "기타", "정규화", "ER 모델링", "DDL", "기본 조회", "조인", "기본 조회", "DML", "그룹 함수", "키 관리", "기본 조회", "윈도우 함수", "집합 연산자", "집계 함수", "키 관리", "키 관리", "기본 조회", "기본 조회", "기본 조회", "기본 조회", "DML", "그룹 함수", "DML", "집계 함수", "기본 조회", "집합 연산자", "서브쿼리", "DDL", "DML", "ER 모델링", "ER 모델링", "ER 모델링", "조인", "그룹 함수", "DML", "정규화", "기본 조회", "조건문/변환함수", "집합 연산자", "기본 조회", "키 관리", "정규화", "ER 모델링", "DDL", "집계 함수", "조인", "키 관리", "키 관리", "집계 함수", "조인", "기본 조회", "키 관리", "조인", "조인", "기타", "집합 연산자", "조인", "DML", "기본 조회", "ER 모델링", "ER 모델링", "DML", "집계 함수", "ER 모델링", "기본 조회", "키 관리", "기타", "DDL", "윈도우 함수", "DML", "기본 조회", "조건문/변환함수", "기타", "집계 함수", "집합 연산자", "집합 연산자", "기본 조회", "기본 조회", "기본 조회", "그룹 함수", "조인", "그룹 함수", "ER 모델링", "그룹 함수", "그룹 함수", "기타", "DML", "ER 모델링", "기타", "기타", "기본 조회", "데이터 무결성", "ER 모델링", "트랜잭션", "기본 조회", "기본 조회", "조인", "조건문/변환함수", "서브쿼리", "기본 조회", "그룹 함수", "조인", "기본 조회", "키 관리", "집계 함수", "기타", "서브쿼리", "조인", "기타", "기본 조회", "DML", "그룹 함수", "그룹 함수", "기타", "기본 조회", "집계 함수", "조인", "기타", "기본 조회", "기본 조회", "키 관리", "기본 조회", "그룹 함수", "기본 조회", "DDL", "기타", "조인", "기타", "키 관리", "기본 조회", "조인", "키 관리", "데이터 무결성", "ER 모델링", "ER 모델링", "ER 모델링", "기본 조회", "기본 조회", "기타", "그룹 함수", "ER 모델링", "기본 조회", "조건문/변환함수", "조인", "조인", "ER 모델링", "ER 모델링", "DDL", "기본 조회", "ER 모델링", "기타", "DML", "기본 조회", "기본 조회", "기타", "기타", "ER 모델링", "기타", "정규화", "윈도우 함수", "ER 모델링", "ER 모델링", "기타", "집계 함수", "집합 연산자", "윈도우 함수", "조인", "윈도우 함수", "조인", "조건문/변환함수", "조건문/변환함수", "그룹 함수"]
len(tags)
# 사용법:
df['category'] = categories
df['tag'] = tags
df.to_csv('data/data_1.csv', encoding='utf-8', index=0)

# %%
df.iloc[:500,:].to_csv('data/data_1.csv', encoding='utf-8', index=0)
df.iloc[501:1000,:].to_csv('data/data_2.csv', encoding='utf-8', index=0)
df.iloc[1000:,:].to_csv('data/data_3.csv', encoding='utf-8', index=0)

# %%
# SQLD 문제 분류 결과 - 판다스 사용법
df = pd.read_csv('data/data_2.csv', encoding='utf-8', index_col=False)

# 카테고리 배열 (1과목/2과목)
categories = ["2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","1과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","1과목","1과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","1과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","1과목","2과목","2과목","1과목","2과목","1과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","1과목","2과목","1과목","2과목","2과목","2과목","2과목","1과목","2과목","2과목","1과목","2과목","2과목","2과목","2과목","2과목","1과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","1과목","1과목","2과목","2과목","2과목","2과목","2과목","1과목","2과목","2과목","2과목","1과목","2과목","2과목","2과목","2과목","1과목","2과목","2과목","2과목","1과목","1과목","2과목","2과목","2과목","1과목","1과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","1과목","1과목","2과목","2과목","1과목","2과목","2과목","1과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","1과목","2과목","1과목","2과목","1과목","2과목","2과목","1과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","1과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","1과목","1과목","1과목","2과목","1과목","1과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","1과목","2과목","2과목","1과목","1과목","1과목","1과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","1과목","2과목","2과목","2과목","1과목","2과목","2과목","2과목","2과목","2과목","2과목","1과목","1과목","2과목","2과목","2과목","1과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","1과목","2과목","1과목","1과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","1과목","2과목","1과목","1과목","1과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","1과목","1과목","2과목","2과목","2과목","1과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","1과목","1과목","1과목","1과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","1과목","1과목","2과목","1과목","1과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","1과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","2과목","1과목","1과목","2과목","2과목","2과목","2과목","2과목","1과목","1과목","1과목","2과목","1과목","2과목","2과목", "1과목","1과목"]

# 태그 배열 (상세 분류)
tags = ["집계 함수, NULL 처리","집계 함수, 그룹 함수, 소계 함수","윈도우 함수","집계 함수, 서브쿼리","집계 함수, 트랜잭션, DML","집계 함수, 윈도우 함수","트랜잭션, DML","조인, 서브쿼리, 집합 연산자, NULL 처리","집계 함수","집계 함수, 그룹 함수","집계 함수, 윈도우 함수","집계 함수, 서브쿼리, 그룹 함수, NULL 처리","조건문","집계 함수","윈도우 함수","집계 함수, 조인","윈도우 함수","윈도우 함수","집계 함수, 서브쿼리","조건문","집계 함수, 서브쿼리, DML","집계 함수, 그룹 함수, NULL 처리","집계 함수, 조인","NULL 처리","집계 함수, 그룹 함수, NULL 처리","기본 SQL","집계 함수, 서브쿼리, 집합 연산자","집계 함수, NULL 처리","집계 함수, 서브쿼리, NULL 처리","기본 SQL","윈도우 함수","집계 함수, 서브쿼리, NULL 처리","NULL 처리","식별자","집계 함수, NULL 처리","집계 함수","기본 SQL","조건문","집계 함수, 그룹 함수, 소계 함수","기본 SQL","NULL 처리","집계 함수, 윈도우 함수","조인, 서브쿼리, NULL 처리","집계 함수, 서브쿼리, 그룹 함수","윈도우 함수","NULL 처리","집계 함수","NULL 처리, 식별자","기본 SQL","집계 함수","DML, DDL, NULL 처리, 식별자","집계 함수, 그룹 함수, 소계 함수","집계 함수","조인","집계 함수, 서브쿼리","집계 함수, 조인, 그룹 함수, 소계 함수, 조건문","트랜잭션, DML, DDL","집계 함수, 서브쿼리","NULL 처리","집계 함수, 서브쿼리","집계 함수, 조인, NULL 처리","집계 함수, 서브쿼리, NULL 처리","서브쿼리, 집합 연산자","집계 함수, 윈도우 함수, 서브쿼리, 그룹 함수","집계 함수, 조인, NULL 처리","윈도우 함수","집계 함수, 그룹 함수, 소계 함수","조인","집계 함수","집계 함수","기본 SQL","조인, 서브쿼리","기본 SQL","조건문","집계 함수, NULL 처리","기본 SQL","기본 SQL","집계 함수, 그룹 함수, 소계 함수","집계 함수, 그룹 함수, NULL 처리","NULL 처리","집계 함수, 서브쿼리","조인","집계 함수, 서브쿼리, 집합 연산자","집계 함수","집계 함수, 서브쿼리, NULL 처리","집계 함수, 조건문","집계 함수, 서브쿼리, 그룹 함수","집계 함수, 그룹 함수","집계 함수, NULL 처리","집계 함수, 서브쿼리, DML","집계 함수, 그룹 함수, 조건문","집계 함수, 그룹 함수, 소계 함수","DML, DDL, NULL 처리","집계 함수, 서브쿼리, NULL 처리","집계 함수, 그룹 함수","집계 함수, 서브쿼리, 그룹 함수, 소계 함수","기본 SQL","집계 함수, NULL 처리","조인, NULL 처리","집계 함수, 서브쿼리, 그룹 함수, NULL 처리","집계 함수, 서브쿼리, 그룹 함수, NULL 처리","집계 함수, 윈도우 함수, 서브쿼리, 그룹 함수","조인, 서브쿼리, NULL 처리","집계 함수, NULL 처리","NULL 처리","집계 함수, 조인, 서브쿼리, NULL 처리","기본 SQL","집계 함수","집계 함수, 서브쿼리, 집합 연산자","집계 함수, 서브쿼리","집계 함수, 그룹 함수, 소계 함수","집계 함수, 윈도우 함수, 서브쿼리, 그룹 함수","집계 함수, 서브쿼리, NULL 처리","윈도우 함수","NULL 처리","NULL 처리","조건문","집계 함수","집계 함수, 서브쿼리","집계 함수, 서브쿼리, 집합 연산자","집계 함수, 서브쿼리, 그룹 함수, 소계 함수","집계 함수, 그룹 함수, NULL 처리","집계 함수","기본 SQL","조건문, NULL 처리","기본 SQL","기본 SQL","집계 함수, 그룹 함수","NULL 처리","NULL 처리","DML, DDL, NULL 처리","집계 함수, 그룹 함수, 소계 함수","기본 SQL","윈도우 함수","집계 함수, 조건문, NULL 처리","기본 SQL","집계 함수","기본 SQL","집계 함수, 서브쿼리, NULL 처리","집계 함수, 조인, 그룹 함수","기본 SQL","기본 SQL","서브쿼리","조인, 서브쿼리, DML, NULL 처리","조인, 서브쿼리, NULL 처리, 식별자","그룹 함수","윈도우 함수","집계 함수, 서브쿼리, DML, DDL","DML","데이터 모델링","식별자, ER 모델링","기본 SQL","집계 함수, 트랜잭션, DML, DDL, NULL 처리","그룹 함수","집계 함수, 윈도우 함수, 그룹 함수","트랜잭션, DML","집계 함수, 트랜잭션, DML, DDL","기본 SQL","집계 함수, 서브쿼리, 집합 연산자","기본 SQL","기본 SQL","서브쿼리","기본 SQL","DDL","트랜잭션, DML, DDL","조인, ER 모델링","기본 SQL","집계 함수","DML","기본 SQL","서브쿼리","기본 SQL","ER 모델링","NULL 처리","식별자, ER 모델링","기본 SQL","정규화","기본 SQL","기본 SQL","ER 모델링","기본 SQL","기본 SQL","윈도우 함수","집계 함수, 조인, 서브쿼리","집계 함수, 그룹 함수","기본 SQL","트랜잭션","기본 SQL","데이터 무결성","기본 SQL","트랜잭션","윈도우 함수","트랜잭션","그룹 함수","기본 SQL","기본 SQL","트랜잭션, DML, DDL","ER 모델링","식별자","ER 모델링","기본 SQL","정규화","ER 모델링","그룹 함수","기본 SQL","기본 SQL","NULL 처리","기본 SQL","서브쿼리, 집합 연산자","기본 SQL","기본 SQL","기본 SQL","기본 SQL","기본 SQL","기본 SQL","그룹 함수","DML, DDL, NULL 처리, 식별자","그룹 함수","그룹 함수","기본 SQL","정규화, ER 모델링","기본 SQL","기본 SQL","ER 모델링","ER 모델링","NULL 처리, 식별자","데이터 모델링","기본 SQL","DDL","기본 SQL","NULL 처리","기본 SQL","NULL 처리","NULL 처리","집계 함수, 트랜잭션, DML, DDL","조인, 서브쿼리, DML, NULL 처리","데이터 모델링","기본 SQL","기본 SQL","기본 SQL","ER 모델링","기본 SQL","그룹 함수, NULL 처리","조인","트랜잭션, DML","NULL 처리","기본 SQL","정규화, 식별자","ER 모델링","DDL","기본 SQL","기본 SQL","데이터 모델링","집계 함수, 서브쿼리, DML, DDL","조인, 서브쿼리, 집합 연산자, NULL 처리","기본 SQL","기본 SQL","기본 SQL","기본 SQL","기본 SQL","조인","소계 함수","기본 SQL","조인","조인, ER 모델링","윈도우 함수","기본 SQL","기본 SQL","그룹 함수","기본 SQL","기본 SQL","데이터 모델링","기본 SQL","데이터 모델링","NULL 처리","집계 함수, 서브쿼리, 집합 연산자, 그룹 함수, 소계 함수","기본 SQL","기본 SQL","조건문","집계 함수, 집합 연산자","트랜잭션","조인, NULL 처리","DML","기본 SQL","집합 연산자","기본 SQL","식별자","기본 SQL","ER 모델링","정규화, ER 모델링","NULL 처리, 식별자","서브쿼리","기본 SQL","서브쿼리, DML, DDL, NULL 처리","기본 SQL","기본 SQL","집계 함수, 트랜잭션, DML, DDL, NULL 처리","기본 SQL","조인, 식별자, ER 모델링","윈도우 함수","기본 SQL","기본 SQL","윈도우 함수","기본 SQL","집계 함수, 그룹 함수","NULL 처리","윈도우 함수","데이터 모델링","ER 모델링","NULL 처리","DML","집계 함수, 서브쿼리, DDL, NULL 처리","식별자","DDL","기본 SQL","윈도우 함수","기본 SQL","DML","트랜잭션","기본 SQL","집계 함수","데이터 모델링","식별자, ER 모델링","데이터 모델링","ER 모델링","기본 SQL","집계 함수, 서브쿼리, NULL 처리","기본 SQL","집합 연산자","기본 SQL","기본 SQL","기본 SQL","ER 모델링","NULL 처리","기본 SQL","ER 모델링","정규화, 데이터 무결성, ER 모델링","기본 SQL","기본 SQL","집계 함수, 그룹 함수","기본 SQL","윈도우 함수","조인","트랜잭션, DDL","식별자","조건문, NULL 처리","집합 연산자","집계 함수, 윈도우 함수, 그룹 함수","조인","트랜잭션","조인","기본 SQL","기본 SQL","기본 SQL","기본 SQL","집계 함수","식별자","NULL 처리, 식별자","기본 SQL","그룹 함수","기본 SQL","집계 함수, 조건문, NULL 처리","NULL 처리","ER 모델링","NULL 처리, 식별자","데이터 모델링","기본 SQL","데이터 모델링","기본 SQL","기본 SQL"]
print(len(categories))
# df['category'] = categories
# df['tag'] = tags

# print(df.shape)
df.tail(3)
# Out:
# 497
#                                                  title  content_img  \
# 496               다음에서 설명하는 것은 ER 모델 중 어떤 항목에 대한 설명인가?          NaN
# 497             다음 중 성능데이터 모델링을 할 때 고려사항으로 가장 부적절한 것은?          NaN
# 498  다음 중 데이터베아스 시스템 언어의 종류와 해당되는 명령어를 바르게 연결한 것을 2...          NaN
#
#                                           content_text  \
# 496  1) 모든 릴레이션은 원자값을 가져야 한다. 2) 어떤 릴레이션에서 속성 값이 가질...
# 497                                                NaN
# 498                                                NaN
#
#                                              choices_1  \
# 496                                                 차수
# 497  이력데이터는 시간에 따라 반복적으로 발생이 되기 때문에 대량 데이터일 가능성이 높아...
# 498                                        DML - ALTER
#
#                                              choices_2  \
# 496                                               인스턴스
# 497  물리적인 데이터 모델링을 할 때 PK/FK의 칼럼의 순서조정, FK인덱스 생성 등은...
# 498                                         DCL - DROP
#
# ...

# %%
a = pd.read_csv('data/first_df.csv', encoding='utf-8', index_col=False).to_string()
# 파일에 저장
with open('data/dataframe.txt', 'w', encoding='utf-8') as f:
    f.write(a)

# %%
df = pd.read_csv('data/sqld_kr_data_20250604_152417.csv', encoding='utf-8')
df[df['tags'].isnull()]
# Out:
#    category tags                                              title  \
# 1       1과목  NaN  다음 중 SELECT COL1 + COL3 FROM TAB_A； 의 결과로 가장 적...
# 4       1과목  NaN                               NULL에 대한 설명으로 틀린 것은?
# 5       1과목  NaN  다음 중 아래와 같은 문장으로 ,학생테이블을 생성한 후,유효한 튜플(Tuple) 들...
# 7       1과목  NaN                        다음 중 NULL의 설명으로 가장 부적절한 것은?
# 56      1과목  NaN                               NULL에 대한 설명으로 틀린 것은?
# 73      2과목  NaN                   다음 보기에서 SELECT 결과가 NULL이 아닌 경우는?
# 92      2과목  NaN              다음 주어진 테이블에서 해당 SQL문을 실행한 결과로 알맞은 것은?
#
#                                           content_img  \
# 1   https://sqld-bk.s3.ap-southeast-2.amazonaws.co...
# 4                                                 NaN
# 5   https://sqld-bk.s3.ap-southeast-2.amazonaws.co...
# 7                                                 NaN
# 56                                                NaN
# 73                                                NaN
# ...

# %%
import pandas as pd
from data_process import *
from glob import glob

files = glob('./data/sqld_kr_data_*.csv')
df = read_files(files)
df = drop_dupli(df)
df = add_answer_commentary(df)
print(df.shape)
df.head()

데이터에 ', ‘, ’ 이것들을 '로 변경해야하고 ：를 :로,；를 ;로 바꾸고, 정답이
정답: 1
해설: ...
이렇게 되어있는걸 정답이랑 해설을 따로 분리해야해요

# %%
import pandas as pd
from data_process import *
from glob import glob

files = glob('./data/*.csv')
df = read_files(files)
df = drop_dupli(df)
df = add_answer_commentary(df)
df.drop(['page_id', 'id', 'answer'], axis=1, inplace=True)
df = processing(df)
print(df.shape)
df.head()
# Out:
# (854, 11)
#   category      tag                                      title  \
# 0      2과목      정규화  다음 중 아래 '일자별매각물건' 엔터티에 대한 설명으로 가장 적절한 것은?
# 1      2과목   ER 모델링               다음의 ERD에 대한 설명으로 올바르지 않은 것은?
# 2      2과목   집합 연산자                다음 중 SQL문을 가장 잘 설명하고 있는 것은?
# 3      2과목    그룹 함수               다음 주어진 SQL문의 빈칸에 그룹 함수를 쓰시오.
# 4      2과목  트랜잭션 관리                   아래 SQL 실행 결과로 가장 적절한 것은?
#
#                                          content_img  \
# 0  https://sqld-bk.s3.ap-southeast-2.amazonaws.co...
# 1  https://sqld-bk.s3.ap-southeast-2.amazonaws.co...
# 2  https://sqld-bk.s3.ap-southeast-2.amazonaws.co...
# 3  https://sqld-bk.s3.ap-southeast-2.amazonaws.co...
# 4  https://sqld-bk.s3.ap-southeast-2.amazonaws.co...
#
#                                         content_text  \
# 0                                                NaN
# 1                                                NaN
# 2  SELECT A.* FROM MytestA A, MytestB B WHERE A.M...
# ...

# %%
df.to_csv('finish_data.csv', encoding='utf-8')

# %%
df = pd.read_csv('finish_data.csv', encoding='utf-8')
for i in df[df['content_img'].notna() & df['content_img'].notna()]['content_img']:
    if not 'https://sqld-bk.s3.ap' in i:
        print(i)
# Out:
# https://cbt.youngjin.com/upload/sqld/133.png
# https://cbt.youngjin.com/upload/sqld/19.png
# https://cbt.youngjin.com/upload/sqld/72.png
# https://cbt.youngjin.com/upload/sqld/132.png
# https://cbt.youngjin.com/upload/sqld/146.png
# https://cbt.youngjin.com/upload/sqld/77.png
# https://cbt.youngjin.com/upload/sqld/74.png
# https://cbt.youngjin.com/upload/sqld/78.png
# https://cbt.youngjin.com/upload/sqld/118.png
# https://cbt.youngjin.com/upload/sqld/130.png
# https://cbt.youngjin.com/upload/sqld/22.png
# https://cbt.youngjin.com/upload/sqld/131.png
# https://cbt.youngjin.com/upload/sqld/63.png
# https://cbt.youngjin.com/upload/sqld/68.png
# https://cbt.youngjin.com/upload/sqld/110.png
# https://cbt.youngjin.com/upload/sqld/148.png
# https://cbt.youngjin.com/upload/sqld/64.png
# https://cbt.youngjin.com/upload/sqld/73.png
# https://cbt.youngjin.com/upload/sqld/127.png
# https://cbt.youngjin.com/upload/sqld/20230828_084538.png
# https://cbt.youngjin.com/upload/sqld/91.png
# ...

# %%
# df[df['content_img'].notnull() & df['content_img' == 'https://sqld-bk.s3.ap-southeast-2.amazonaws.com/j34-1.png']]
# df[df['content_img'] == 'https://sqld-bk.s3.ap-southeast-2.amazonaws.com/j36-1.png']

import os

file = os.path.basename('https://sqld-bk.s3.ap-southeast-2.amazonaws.com/j36-1.png')
file_name = os.path.splitext(file)[0]
file_name
# Out:
# 'j36-1'
